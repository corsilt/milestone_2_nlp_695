# %%
import pandas as pd
from pycaret.classification import *

# %%
#df_ranks = pd.read_csv(r'C:\Users\corsi\Downloads\umich-siads-695-fall21-predicting-text-difficulty\df_train_with_ranks.csv')
df = pd.read_csv(r'C:\Users\corsi\Downloads\umich-siads-695-fall21-predicting-text-difficulty\final_df_ranks.csv')

# %%
cols = ['nums', 
'oov_rank', 
'stop_word', 
'oov_rank_no_punc', 
'punct_lemm', 
'punct', 
'word_len_no_punc', 
'word_len', 
'basic_rank_no_punc', 
'word_count_no_punct', 
'word_count', 
'sent_len', 
'aol_rank_no_punc_perc', 
'aol_rank_perc', 
'concreteness_rank_no_punc_perc', 
'concreteness_rank_perc',
'basic_rank', 
'mid_con', 
'bot_aol', 
'mid_aol', 
'top_aol', 
'bot_con', 
'top_con', 
'basic_sim',
'label']

# %%
df = df.drop( columns=['original_text','Unnamed: 0' ])

# %%
#df = df[cols]
objs = ['mid_con', 'bot_aol', 'mid_aol', 'top_aol', 'bot_con', 'top_con',
       'basic_sim']

# %%
def make_float(col):
  return (eval(col))[0]

# %%
for i in objs:
  df[i] = df[i].apply(make_float)

# %%
# df.to_csv(r'C:\Users\corsi\Downloads\umich-siads-695-fall21-predicting-text-difficulty\df_train_with_ranks2.csv')

# %%
# df = pd.read_csv(r'C:\Users\corsi\Downloads\umich-siads-695-fall21-predicting-text-difficulty\df_train_with_ranks.csv')

# %%
# df = df[cols].dropna()

# %%
df.dtypes
# Out:
# Unnamed: 0                              int64
# original_text                          object
# label                                   int64
# top_aol                                object
# mid_aol                                object
# bot_aol                                object
# top_con                                object
# mid_con                                object
# bot_con                                object
# basic_sim                              object
# basic_rank                            float64
# basic_rank_no_punc                    float64
# oov_rank                              float64
# oov_rank_no_punc                      float64
# word_len                              float64
# word_len_no_punc                      float64
# sent_len                                int64
# word_count_no_punct                     int64
# word_count                              int64
# punct                                   int64
# ...

# %%
clf = setup(df, target='label', session_id=123,
            preprocess=True, silent=True,use_gpu=True, normalize=True)
# Out:
# <style type="text/css">
# #T_63f53_row5_col1, #T_63f53_row18_col1, #T_63f53_row29_col1, #T_63f53_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_63f53_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63f53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63f53_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_63f53_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_63f53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63f53_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_63f53_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_63f53_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# best_model = compare_models(exclude=['qda','lda'], fold=2)
# Out:
# IntProgress(value=0, description='Processing: ', max=64)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                17:14:15
# Status     . . . . . . . . . . . . . . . . . .         Fitting 2 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# <style type="text/css">
# #T_846f0_ th {
#   text-align: left;
# }
# #T_846f0_row0_col0, #T_846f0_row0_col1, #T_846f0_row0_col2, #T_846f0_row0_col3, #T_846f0_row0_col4, #T_846f0_row0_col5, #T_846f0_row0_col6, #T_846f0_row0_col7, #T_846f0_row0_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_846f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
# ...

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_b1382_row10_col0, #T_b1382_row10_col1, #T_b1382_row10_col2, #T_b1382_row10_col3, #T_b1382_row10_col4, #T_b1382_row10_col5, #T_b1382_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b1382_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1382_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1382_row0_col0" class="data row0 col0" >0.7008</td>
#       <td id="T_b1382_row0_col1" class="data row0 col1" >0.7907</td>
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_7b57d_row10_col0, #T_7b57d_row10_col1, #T_7b57d_row10_col2, #T_7b57d_row10_col3, #T_7b57d_row10_col4, #T_7b57d_row10_col5, #T_7b57d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7b57d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b57d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b57d_row0_col0" class="data row0 col0" >0.6496</td>
#       <td id="T_7b57d_row0_col1" class="data row0 col1" >0.7078</td>
# ...
